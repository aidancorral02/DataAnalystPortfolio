# %% [markdown]
# # Import Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %% [markdown]
# # Read Data

# %%
df = pd.read_csv('C:/Users/HP/Documents/Data_Analyst_Portfolio_Projects/movies.csv')
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.shape
# Out:
# (7668, 15)

# %%
df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')

# %% [markdown]
# # Count Null Values per Column

# %%
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %% [markdown]
# # Summary Stats per Column

# %%
df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.665000e+03  5.497000e+03  7.479000e+03
# mean   2000.405451     6.390411  8.810850e+04  3.558988e+07  7.850054e+07
# std      11.153508     0.968842  1.633238e+05  4.145730e+07  1.657251e+08
# min    1980.000000     1.900000  7.000000e+00  3.000000e+03  3.090000e+02
# 25%    1991.000000     5.800000  9.100000e+03  1.000000e+07  4.532056e+06
# 50%    2000.000000     6.500000  3.300000e+04  2.050000e+07  2.020576e+07
# 75%    2010.000000     7.100000  9.300000e+04  4.500000e+07  7.601669e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %% [markdown]
# # Columns sorted per Gross Income

# %%
df.sort_values(by=['gross'], ascending = False, inplace = False).head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country       budget  \
# ...

# %%
df.sort_values(by=['gross'], ascending = False, inplace = False).tail(10)
# Out:
#                            name rating   genre  year  \
# 7654   Star Trek First Frontier    NaN  Sci-Fi  2020
# 7658  Black Wall Street Burning      R   Drama  2020
# 7660           Aloha Surf Hotel    NaN  Comedy  2020
# 7661           Love by Drowning      R   Drama  2020
# 7662              The Robinsons    NaN  Action  2020
# 7663               More to Life    NaN   Drama  2020
# 7664                Dream Round    NaN  Comedy  2020
# 7665              Saving Mbango    NaN   Drama  2020
# 7666               It's Just Us    NaN   Drama  2020
# 7667                  Tee em el    NaN  Horror  2020
#
#                                released  score  votes            director  \
# 7654  September 8, 2020 (United States)    5.7  165.0       Kenneth Smith
# 7658   February 7, 2020 (United States)    6.6   35.0        Marcus Brown
# 7660   November 5, 2020 (United States)    7.1   14.0  Stefan C. Schaefer
# 7661   November 6, 2020 (United States)    NaN    NaN   Justin Kreinbrink
# ...

# %% [markdown]
# # Scatter Plot (Budget vs Gross Income)

# %%
sns.relplot(data=df, x='budget', y='gross', alpha=0.5)
plt.title("Budget vs. gross income");

# %%
sns.regplot(data=df, x='budget', y='gross', scatter_kws={'alpha':0.5}, line_kws={'color': 'green'});

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17948\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
corr_matrix = df.corr(method='pearson')
plt.figure(figsize=(10,10))
sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation of variables')
plt.xlabel('Movie features')
plt.ylabel('Movie features');
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17948\1964246642.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr(method='pearson')

# %%
corr_pairs = corr_matrix.unstack()
corr_pairs
# Out:
# year     year       1.000000
#          score      0.097995
#          votes      0.222945
#          budget     0.329321
#          gross      0.257486
#          runtime    0.120811
# score    year       0.097995
#          score      1.000000
#          votes      0.409182
#          budget     0.076254
#          gross      0.186258
#          runtime    0.399451
# votes    year       0.222945
#          score      0.409182
#          votes      1.000000
#          budget     0.442429
#          gross      0.630757
#          runtime    0.309212
# budget   year       0.329321
#          score      0.076254
#          votes      0.442429
#          budget     1.000000
#          gross      0.740395
#          runtime    0.320447
# gross    year       0.257486
#          score      0.186258
#          votes      0.630757
#          budget     0.740395
#          gross      1.000000
#          runtime    0.245216
# runtime  year       0.120811
#          score      0.399451
# ...

# %%
corr_pairs.sort_values()[corr_pairs.sort_values() > 0.5]
# Out:
# votes    gross      0.630757
# gross    votes      0.630757
# budget   gross      0.740395
# gross    budget     0.740395
# year     year       1.000000
# budget   budget     1.000000
# votes    votes      1.000000
# score    score      1.000000
# gross    gross      1.000000
# runtime  runtime    1.000000
# dtype: float64

# %%
sns.pairplot(df);
